# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoshitha61/PP/blob/main/CSVFiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("WELCOME TO THE KINGDOM!")
print('Choose')

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/greenhouse-gas-emissions-by-region-industry-and-household-year-ended-2023.csv')
data
# Out:
#           Region                                  Anzsic_descriptor  \
# 0       Auckland  Forestry and logging, fishing, and agricultura...
# 1       Auckland  Forestry and logging, fishing, and agricultura...
# 2       Auckland  Forestry and logging, fishing, and agricultura...
# 3       Auckland  Forestry and logging, fishing, and agricultura...
# 4       Auckland  Forestry and logging, fishing, and agricultura...
# ...          ...                                                ...
# 7833  West Coast                                              Total
# 7834  West Coast                                              Total
# 7835  West Coast                                              Total
# 7836  West Coast                                              Total
# 7837  West Coast                                              Total
#
#      Sub_industry Household_category                         Gas  Year  \
# 0           Total              Total  Carbon dioxide equivalents  2007
# ...

# %%
data.head(10)
# Out:
#      Region                                  Anzsic_descriptor Sub_industry  \
# 0  Auckland  Forestry and logging, fishing, and agricultura...        Total
# 1  Auckland  Forestry and logging, fishing, and agricultura...        Total
# 2  Auckland  Forestry and logging, fishing, and agricultura...        Total
# 3  Auckland  Forestry and logging, fishing, and agricultura...        Total
# 4  Auckland  Forestry and logging, fishing, and agricultura...        Total
# 5  Auckland  Forestry and logging, fishing, and agricultura...        Total
# 6  Auckland  Forestry and logging, fishing, and agricultura...        Total
# 7  Auckland  Forestry and logging, fishing, and agricultura...        Total
# 8  Auckland  Forestry and logging, fishing, and agricultura...        Total
# 9  Auckland  Forestry and logging, fishing, and agricultura...        Total
#
#   Household_category                         Gas  Year  Data_value  \
# ...

# %%
data.tail()
# Out:
#           Region Anzsic_descriptor Sub_industry Household_category  \
# 7833  West Coast             Total        Total              Total
# 7834  West Coast             Total        Total              Total
# 7835  West Coast             Total        Total              Total
# 7836  West Coast             Total        Total              Total
# 7837  West Coast             Total        Total              Total
#
#                              Gas  Year  Data_value       Units  \
# 7833  Carbon dioxide equivalents  2023     1172.55  Kilotonnes
# 7834              Carbon dioxide  2023      447.26  Kilotonnes
# 7835                     Methane  2023      593.49  Kilotonnes
# 7836               Nitrous oxide  2023      121.45  Kilotonnes
# 7837           Fluorinated gases  2023       10.36  Kilotonnes
#
#                        Magnitude
# 7833  Carbon dioxide equivalents
# 7834  Carbon dioxide equivalents
# 7835  Carbon dioxide equivalents
# 7836  Carbon dioxide equivalents
# ...

# %%
data.sample()
# Out:
#           Region                                  Anzsic_descriptor  \
# 110  Marlborough  Forestry and logging, fishing, and agricultura...
#
#     Sub_industry Household_category                         Gas  Year  \
# 110        Total              Total  Carbon dioxide equivalents  2021
#
#      Data_value       Units                   Magnitude
# 110       60.24  Kilotonnes  Carbon dioxide equivalents

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7838 entries, 0 to 7837
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Region              7838 non-null   object
#  1   Anzsic_descriptor   7838 non-null   object
#  2   Sub_industry        7838 non-null   object
#  3   Household_category  7838 non-null   object
#  4   Gas                 7838 non-null   object
#  5   Year                7838 non-null   int64
#  6   Data_value          7838 non-null   float64
#  7   Units               7838 non-null   object
#  8   Magnitude           7838 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 551.2+ KB

# %%
data.size
# Out:
# 70542

# %%
data.shape
# Out:
# (7838, 9)

# %%
data.describe()
# Out:
#               Year    Data_value
# count  7838.000000   7838.000000
# mean   2014.862210   1007.122644
# std       4.826493   2089.009451
# min    2007.000000      0.130000
# 25%    2011.000000     36.822500
# 50%    2015.000000    141.825000
# 75%    2019.000000    886.747500
# max    2023.000000  17592.720000

# %%
data.ndim
# Out:
# 2

# %%
data.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-29a79790751a> in <cell line: 1>()
# ----> 1 data.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
